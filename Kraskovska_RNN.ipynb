# %% [markdown]
# Лабораторна робота 2
#
# студентки групи ФІТ 4-4
#
# Красковської Анастасії Олександрівни
#
# **ЗАВДАННЯ 2**
#
# Побудувати двонаправлену RNN для розрахунку функції із шумом.
# Підібрати власну архитектуру, кількість шарів, функції активації.
# Побудувати графік.
# N = 10000
# data = np.array([np.функція for x in range(N)]) + 0.1*np.random.randn(N)
# В якості функції взяти тригонометричну функцію, наприклад
# 𝑐𝑜𝑠(3𝑥) , 𝑠𝑖𝑛(𝑥 ∕ 5) , 𝑠𝑖𝑛(𝑥 + 3) ∕ 2 і тд.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# Генеруємо дані
N = 10000
X = np.random.rand(N) * 10  # генеруємо N точок від 0 до 10
Y = np.cos(3*X) + 0.1 * np.random.randn(N)  # вхідні дані - косинус з шумом

# Побудова моделі нейронної мережі
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, input_shape=(1,), activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# Компіляція моделі
model.compile(optimizer='adam', loss='mse')

# Навчання моделі та збереження історії навчання
history = model.fit(X, Y, epochs=10, batch_size=32, verbose=1)

# Передбачення за допомогою моделі
predictions = model.predict(X)

# Побудова графіків
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.scatter(X, Y, label='Дані')
plt.scatter(X, predictions, color='r', label='Прогнози')
plt.title('Співставлення Даних та Прогнозів')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title('Функція Втрат')
plt.xlabel('Епохи')
plt.ylabel('Втрати')

plt.show()
# Out:
# Epoch 1/10
# 313/313 [==============================] - 6s 7ms/step - loss: 0.5039
# Epoch 2/10
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4868
# Epoch 3/10
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4840
# Epoch 4/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4810
# Epoch 5/10
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4801
# Epoch 6/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4647
# Epoch 7/10
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4426
# Epoch 8/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4249
# Epoch 9/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4181
# Epoch 10/10
# ...
# 313/313 [==============================] - 1s 2ms/step
